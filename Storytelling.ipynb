# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
beauty_under_20 = pd.read_csv('../Hey-I-am-a-data-analyst/Data/final_makeup_20.csv')

# %%
beauty_under_20
# Out:
#          id                    brand              category  \
# 0   2036408  Anastasia Beverly Hills              Lipstick
# 1   1962695  Anastasia Beverly Hills              Lipstick
# 2   1941970  Anastasia Beverly Hills             Eyeshadow
# 3   2093565  Anastasia Beverly Hills             Lip Gloss
# 4   1307859                 CLINIQUE  Lip Balm & Treatment
# 5   2327245  FENTY BEAUTY by Rihanna             Lip Gloss
# 6   2156487  FENTY BEAUTY by Rihanna              Lipstick
# 7   1725639              HUDA BEAUTY       False Eyelashes
# 8   1958917              HUDA BEAUTY             Lip Gloss
# 9   1914209         KVD Vegan Beauty             Lip Liner
# 10  2072437         MAKE UP FOR EVER              Eyeliner
# 11  2033454         MAKE UP FOR EVER             Eyeshadow
# 12  1005438         MAKE UP FOR EVER             Lip Liner
# 13  1118033       SEPHORA COLLECTION              Eyeliner
# 14  2222099       SEPHORA COLLECTION            Foundation
# ...

# %% [markdown]
# After applying the previus analysis to obtain the top trending products available online, it's possible to share this csv file with both, the sales and marketing team to guide them on the branding promotion process.

# %%
figbeauty_under_20.brand.value_counts()
# Out:
# SEPHORA COLLECTION         13
# Anastasia Beverly Hills     4
# MAKE UP FOR EVER            3
# FENTY BEAUTY by Rihanna     2
# HUDA BEAUTY                 2
# KVD Vegan Beauty            1
# tarte                       1
# CLINIQUE                    1
# Urban Decay                 1
# Name: brand, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='brand', data=beauty_under_20).set_title("The Most Popular Brands");

# %% [markdown]
# Based on this graph, it's clear that we must promote products from our own brand on top of the 'Beauty Under $20' section, and subsequently place the rest of the products' brands.

# %%
Image("../Hey-I-am-a-data-analyst/images/makeup_20_page.png")

# %% [markdown]
# We could also use this data to promote them on the Sephora Email Marketing Strategy and Campaigns

# %%
Image("../Hey-I-am-a-data-analyst/images/email_1.png")

# %%
Image("../Hey-I-am-a-data-analyst/images/email_2.png")

# %%
Image("../Hey-I-am-a-data-analyst/images/email_3.png")

# %%
Image("../Hey-I-am-a-data-analyst/images/email_4.png")
